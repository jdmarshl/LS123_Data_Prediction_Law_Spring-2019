# %% [markdown]
# # [LEGALST-190] Lab 3/20: TF-IDF and Classification

# %% [markdown]
# <img src = "https://cdn.sstatic.net/Sites/stackoverflow/company/img/logos/se/se-logo.png?v=dd7153fcc7fa" style = "width:500px; height: 275px;" />
#
# This lab will cover the term frequency-inverse document frequency method, and classification algorithms in machine learning.
#
# Estimated Lab time: 30 minutes

# %%
# Dependencies
# from datascience import *
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.stop_words import ENGLISH_STOP_WORDS
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.metrics import confusion_matrix
from sklearn import svm
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB
import itertools
import seaborn as sn
# %matplotlib inline

# %% [markdown]
# # The Data

# %% [markdown]
# For this lab, we'll use a dataset that was drawn from a Kaggle collection of questions posed on stackexchange (a website/forum where people ask and answer questions about statistics, programming etc.)
#
# The data has the following features:
#
# - "Id": The Id number for the question
# - "Body": The text of the answer
# - "Tag": Whether the question was tagged as dealing with python, xml, java, json, or android
#
# Your task will be to extract features from the "Body" column, and use those features to predict class membership, denoted by "Tag."

# %%
stack_data = pd.read_csv('data/stackexchange.csv', encoding='latin-1')
stack_data.head(5)
# Out:
#    Unnamed: 0        Id                                               Body  \
# 0           1  26739211  <p>When I initialized my web client id and and...
# 1           2  23589964  <p>I think you need XMPP messaging. It's suppo...
# 2           3  28713425  <p>found in <a href="http://android-scripting....
# 3           4  27410741  <p>Did you try looking at the doc?</p>\r\n\r\n...
# 4           5  26013896  <p>you can use <strong>adb shell logcat</stron...
#
#        Tag
# 0  android
# 1  android
# 2  android
# 3  android
# 4  android

# %% [markdown]
# # Section 1: TF-IDF Vectorizer

# %% [markdown]
# The term frequency-inverse document frequency (tf-idf) vectorizer is a statistic that measures similarity within and across documents. Term frequency refers to the number of times a term shows up within a document. Inverse document frequency is the logarithmically scaled inverse fraction of the documents that contains the word, and penalizes words that occur frequently. Tf-idf multiplies these two measures together.
#
# Check out the documentation [here](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html).

# %% [markdown]
# #### Question 1: Why is tf-idf a potentially more attractive vectorizer than the standard count vectorizer?

# %% [markdown]
# <b> tf-idf is more attractive since the standardized count vectorizer standardizes by word length of the
#     document, and so does not find words that really characterize a particular document relative to all the other documents in a corpus.</b> Also, wouldn't a standardized count vectorizer overweight common words in short documents?

# %% [markdown]
# Let's get started! First, extract the "Body" column into its own numpy array called "text_list"

# %%
# Extract Text Data
text_list = stack_data['Body']
text_list[:5]
# Out:
# 0    <p>When I initialized my web client id and and...
# 1    <p>I think you need XMPP messaging. It's suppo...
# 2    <p>found in <a href="http://android-scripting....
# 3    <p>Did you try looking at the doc?</p>\r\n\r\n...
# 4    <p>you can use <strong>adb shell logcat</stron...
# Name: Body, dtype: object

# %% [markdown]
# Next, initialize a term frequency-inverse document frequency (tf-idf) vectorizer. Check out the documentation to fill in the arguments: http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %%
tf = TfidfVectorizer(analyzer='word',        #I called the vectorizer with different arguments the first time
                     ngram_range=(1,3), 
                     min_df = 0, 
                     stop_words = 'english')

# %% [markdown]
# Next, use the "fit_transform" method to take in the list of documents, and convert them into a document term matrix. Use "get_feature_names()" and "len" to calculate how many features this generates.

# %%
tfidf_matrix = tf.fit_transform(text_list)
print(type(tfidf_matrix))
print('tfidf_matrix: rows, columns', tfidf_matrix.shape)
feature_names = tf.get_feature_names()
feature_names
# Out:
# <class 'scipy.sparse.csr.csr_matrix'>
# tfidf_matrix: rows, columns (2500, 154834)
# ['00',
#  '00 00',
#  '00 00 00',
#  '00 00 2015',
#  '00 00 code',
#  '00 00 columns',
#  '00 00 does',
#  '00 00 fetchall',
#  '00 00 nan',
#  '00 05',
#  '00 05 00',
#  '00 10',
#  '00 10 00',
#  '00 12',
#  '00 12 02',
#  '00 15',
#  '00 15 00',
#  '00 2015',
#  '00 2015 07',
#  '00 code',
#  '00 code pre',
#  '00 columns',
#  '00 columns dt',
#  '00 does',
#  '00 does set',
#  '00 fetchall',
#  '00 fetchall print',
#  '00 nan',
#  '00 nan 2015',
#  '00 nan nan',
#  '00 pdt',
#  '00 pdt 2011',
#  '00 pm',
#  '00 pm following',
#  '00 pm lt',
#  '00 pm value',
#  '00 time',
#  '00 time 14',
#  '000',
#  '000 000',
#  '000 000 000',
#  '000 000 code',
#  '000 000 function',
#  '000 032',
#  '000 032 033',
#  '000 033',
#  '000 033 032',
#  '000 109',
#  '000 109 600',
#  '000 110',
#  '000 110 951',
#  '000 38',
#  '000 38 144',
#  '000 aea',
#  '000 aea investors',
#  '000 code',
#  '000 code achieve',
#  '000 code pre',
#  '000 firm',
#  '000 firm tencent',
#  '000 firm xxx',
#  '000 function',
#  '000 function result',
#  '000 id',
#  '000 id techventures',
#  '000 images',
#  '000 images time',
#  '000 semi',
#  '000 semi random',
#  '000 server',
#  '000 server c2',
#  '000 sk',
#  '000 sk ventures',
#  '0000',
#  '0000 0000',
#  '0000 0000 0000',
#  '0000 0000 0001',
#  '0000 0001',
#  '0000 0001 0001',
#  '0000 0001 0010',
#  '0000 0010',
#  '0000 0010 0010',
#  '0000 0010 0011',
#  '0000 0011',
#  '0000 0011 0011',
#  '0000 0011 0100',
#  '0000 0100',
#  '0000 0100 0100',
#  '0000 0100 0101',
#  '0000 0101',
#  '0000 0101 0101',
#  '0000 0101 0110',
#  '0000 0110',
#  '0000 0110 0110',
#  '0000 0110 0111',
#  '0000 0111',
#  '0000 0111 0111',
#  '0000 10',
#  '0000 10 1001',
#  '0000 1000',
#  '0000 1000 1000',
#  '0000 1000 1001',
#  '0000 1001',
#  '0000 1001 1001',
#  '0000 1010',
#  '0000 1010 10',
#  '0000 15',
#  '0000 15 0111',
#  '0000 gt',
#  '0000 gt gt',
#  '000000',
#  '000000 250000',
#  '000000 250000 562500',
#  '000000 println',
#  '000000 println function',
#  '000000 private',
#  '000000 private static',
#  '0001',
#  '0001 0000',
#  '0001 0000 0001',
#  '0001 0000 0010',
#  '0001 0001',
#  '0001 0001 0000',
#  '0001 0010',
#  '0001 0010 0011',
#  '0001 0010 0100',
#  '0001 0011',
#  '0001 0011 0010',
#  '0001 0100',
#  '0001 0100 0101',
#  '0001 0100 0110',
#  '0001 0101',
#  '0001 0101 0100',
#  '0001 0110',
#  '0001 0110 0111',
#  '0001 0111',
#  '0001 0111 0110',
#  '0001 10',
#  '0001 10 1000',
#  '0001 1000',
#  '0001 1000 1001',
#  '0001 1001',
#  '0001 1001 1000',
#  '0001 1010',
#  '0001 1010 10',
#  '0001 14',
#  '0001 14 0110',
#  '0008',
#  '0008 pep',
#  '0008 pep style',
#  '000ms',
#  '000ms minute',
#  '001',
#  '001 002',
#  '001 time',
#  '001 time experience',
#  '0010',
#  '0010 0000',
#  '0010 0000 0010',
#  '0010 0000 0011',
#  '0010 0001',
#  '0010 0001 0100',
#  '0010 0010',
#  '0010 0010 0000',
#  '0010 0011',
#  '0010 0011 0001',
#  '0010 0100',
#  '0010 0100 0110',
#  '0010 0100 0111',
#  '0010 0101',
#  '0010 0101 0111',
#  '0010 0110',
#  '0010 0110 0100',
#  '0010 0111',
#  '0010 0111 0101',
#  '0010 1000',
#  '0010 1000 1010',
#  '0010 1001',
#  '0010 1001 1001',
#  '0010 1001 1011',
#  '0010 1010',
#  '0010 1010 10',
#  '0010 13',
#  '0010 13 0101',
#  '0011',
#  '0011 0000',
#  '0011 0000 0011',
#  '0011 0000 0100',
#  '0011 0001',
#  '0011 0001 0010',
#  '0011 0001 0011',
#  '0011 0010',
#  '0011 0010 0001',
#  '0011 0011',
#  '0011 0011 0000',
#  '0011 0100',
#  '0011 0100 0111',
#  '0011 0101',
#  '0011 0101 0110',
#  '0011 0101 0111',
#  '0011 0110',
#  '0011 0110 0101',
#  '0011 0111',
#  '0011 0111 0100',
#  '0011 10',
#  '0011 10 10',
#  '0011 1000',
#  '0011 1000 1011',
#  '0011 1001',
#  '0011 1001 1010',
#  '0011 1010',
#  '0011 1010 10',
#  '0011 12',
#  '0011 12 0100',
#  '002',
#  '0020',
#  '0020 rel',
#  '0020 rel nofollow',
#  '00216',
#  '00216 references',
#  '00216 references date',
#  '00261401937956',
#  '00261401937956 separ',
#  '00261401937956 separ join',
#  '00292467338726',
#  '00292467338726 os',
#  '00292467338726 os sep',
#  '0030',
#  '0030 aelao',
#  '0030 aelao index',
#  '00330824168994',
#  '00330824168994 winnt',
#  '00330824168994 winnt system32',
#  '00375075603184',
#  '00375075603184 winnt',
#  '00375075603184 winnt system32',
#  '00398598145854',
#  '00398598145854 winnt',
#  '00398598145854 winnt system32',
#  '007f01017a275679706f0004',
#  '007f01017a275679706f0004 path',
#  '007f01017a275679706f0004 path domain',
#  '008c',
#  '008c 2705',
#  '008c 2705 encode',
#  '008c 2705 gt',
#  '008c 2705 ihappy',
#  '008c 2705 u0001f534',
#  '009',
#  '009 cond',
#  '009 cond 80e',
#  '00a0',
#  '00a0 00bd',
#  '00a0 00bd ed',
#  '00b3',
#  '00b3 008c',
#  '00b3 008c 2705',
#  '00b4',
#  '00b4 00b4',
#  '00b4 00b4 0no',
#  '00b4 00b4 ed',
#  '00b4 0no',
#  '00b4 0no 2668',
#  '00b4 ed',
#  '00b4 ed 00a0',
#  '00bd',
#  '00bd ed',
#  '00bd ed 00b3',
#  '00bd ed 00b4',
#  '00f6',
#  '00f6 latin',
#  '00f6 latin small',
#  '00f6 rel',
#  '00f6 rel nofollow',
#  '01',
#  '01 02',
#  '01 02 40060635109',
#  '01 11',
#  '01 11 2015',
#  '01 1992',
#  '01 1992 code',
#  '01 1992 gt',
#  '01 821',
#  '01 821 0030',
#  '01 double',
#  '01 double nd',
#  '01 html',
#  '01 html rel',
#  '01 python',
#  '01 python generators',
#  '01 quick',
#  '01 quick wizard',
#  '01 rdf',
#  '01 rdf schema',
#  '010',
#  '010 0o10',
#  '010 0o10 py3',
#  '0100',
#  '0100 0000',
#  '0100 0000 0100',
#  '0100 0000 0101',
#  '0100 0001',
#  '0100 0001 0110',
#  '0100 0010',
#  '0100 0010 0111',
#  '0100 0100',
#  '0100 0100 0000',
#  '0100 0101',
#  '0100 0101 0001',
#  '0100 0110',
#  '0100 0110 0010',
#  '0100 0111',
#  '0100 0111 0011',
#  '0100 1000',
#  '0100 1000 1100',
#  '0100 1001',
#  '0100 1001 1101',
#  '0100 1010',
#  '0100 1010 10',
#  '0100 11',
#  '0100 11 0011',
#  '0101',
#  '0101 0000',
#  '0101 0000 0101',
#  '0101 0000 0110',
#  '0101 0001',
#  '0101 0001 0100',
#  '0101 0001 0101',
#  '0101 0011',
#  '0101 0011 0111',
#  '0101 0100',
#  '0101 0100 0001',
#  '0101 0101',
#  '0101 0101 0000',
#  '0101 0110',
#  '0101 0110 0011',
#  '0101 0111',
#  '0101 0111 0010',
#  '0101 10',
#  '0101 10 0010',
#  '0101 1000',
#  '0101 1000 1101',
#  '0101 1001',
#  '0101 1001 1100',
#  '0101 1010',
#  '0101 1010 10',
#  '01011',
#  '01011 base',
#  '01011 base code',
#  '0110',
#  '0110 0000',
#  '0110 0000 0110',
#  '0110 0000 0111',
#  '0110 0001',
#  '0110 0001 1000',
#  '0110 0010',
#  '0110 0010 0100',
#  '0110 0010 0101',
#  '0110 0011',
#  '0110 0011 0101',
#  '0110 0011 0110',
#  '0110 0100',
#  '0110 0100 0010',
#  '0110 0101',
#  '0110 0101 0011',
#  '0110 0110',
#  '0110 0110 0000',
#  '0110 0111',
#  '0110 0111 0001',
#  '0110 1000',
#  '0110 1000 1110',
#  '0110 1001',
#  '0110 1001 1111',
#  '0110 1010',
#  '0110 1010 10',
#  '0111',
#  '0111 0000',
#  '0111 0000 1000',
#  '0111 0000 15',
#  '0111 0001',
#  '0111 0001 0111',
#  '0111 0001 14',
#  '0111 0010',
#  '0111 0010 0110',
#  '0111 0010 13',
#  '0111 0011',
#  '0111 0011 0101',
#  '0111 0011 12',
#  '0111 0100',
#  '0111 0100 11',
#  '0111 0101',
#  '0111 0101 10',
#  '0111 0110',
#  '0111 0110 0001',
#  '0111 0111',
#  '0111 0111 0000',
#  '0111 1000',
#  '0111 1000 1111',
#  '0111 1001',
#  '0111 1001 1110',
#  '0111 1010',
#  '0111 1010 10',
#  '0123456789',
#  '0123456789 print',
#  '0123456789 print list',
#  '0123456789 sub',
#  '0123456789 sub sub',
#  '015625',
#  '015625 green',
#  '015625 green line',
#  '0183',
#  '0183 nmea',
#  '0183 nmea 2000',
#  '02',
#  '02 01',
#  '02 01 python',
#  '02 19',
#  '02 19 cold',
#  '02 2013',
#  '02 2013 loggedin',
#  '02 21',
#  '02 21 hxm',
#  '02 40060635109',
#  '02 40060635109 href',
#  '02 40060635109 rel',
#  '02 install',
#  '02 install pip',
#  '020',
#  '020 htp',
#  '020 htp pygtk',
#  '026',
#  '026 durbin',
#  '026 durbin watson',
#  '0272489939364',
#  '0272489939364 ospathjoin',
#  '0272489939364 ospathjoin winnt',
#  '0277652606686',
#  '0277652606686 ospath',
#  '0277652606686 ospath join',
#  '028114',
#  '028114 032250',
#  '028114 032250 138368',
#  '0284533369465',
#  '0284533369465 os',
#  '0284533369465 os path',
#  '02d_',
#  '02d_ s_blue',
#  '02d_ s_blue pdf',
#  '02d_blue',
#  '02d_blue pdf',
#  '02d_blue pdf new_name',
#  '03',
#  '03 01',
#  '03 01 1992',
#  '03 01 quick',
#  '03 06',
#  '03 06 california',
#  '03 13',
#  '03 13 game',
#  '03 1989',
#  '03 1989 21',
#  '03 1989 seth',
#  '03 22',
#  '03 22 ted',
#  '03 26',
#  '03 26 tuntap',
#  '03 documentation',
#  '03 documentation html',
#  '03 wn',
#  '03 wn wn20',
#  '032',
#  '032 033',
#  '032 033 opppts',
#  '032 omnibus',
#  '032 omnibus 026',
#  '032250',
#  '032250 138368',
#  '032250 138368 541577',
#  '0326',
#  '0326 000',
#  '0326 000 109',
#  '0326 000 110',
#  '032x',
#  '032x iv_counter',
#  '032x iv_counter decode',
#  '033',
#  '033 032',
#  '033 032 omnibus',
#  '033 opppts',
#  '033 opppts 0326',
#  '0343',
#  '0343 rel',
#  '0343 rel nofollow',
#  '04',
#  '04 10',
#  '04 10 monkeyrunner',
#  '04 16',
#  '04 16 periodic',
#  '04 21',
#  '04 21 embedding',
#  '04 64',
#  '04 64 bit',
#  '04 build',
#  '04 build executable',
#  '04 rel',
#  '04 rel nofollow',
#  '04 set',
#  '04 set ulimit',
#  '04 shell',
#  '04 shell launcher',
#  '045',
#  '045 400',
#  '045 400 169',
#  '0458',
#  '0458 3782',
#  '0458 3782 2303',
#  '0458 nan',
#  '0458 nan 5328',
#  '04b',
#  '04b 04b',
#  '04b 04b 04b',
#  '04b 04b format',
#  '04b format',
#  '04b format 0000',
#  '05',
#  '05 00',
#  '05 00 00',
#  '05 00 05',
#  '05 00 10',
#  '05 00 15',
#  '05 00 nan',
#  '05 05',
#  '05 05 00',
#  '05 18',
#  '05 18 ar2010051801676',
#  '05 indicate',
#  '05 indicate strong',
#  '05 log',
#  '05 log likelihood',
#  '05 monkeyrunner',
#  '05 monkeyrunner importerror',
#  '05 warnings',
#  '05 warnings standard',
#  '056995',
#  '056995 33',
#  '056995 33 416570',
#  '0596001886_pythonian',
#  '0596001886_pythonian chp',
#  '0596001886_pythonian chp 25',
#  '06',
#  '06 04',
#  '06 04 set',
#  '06 12',
#  '06 12 1990',
#  '06 1991',
#  '06 1991 28',
#  '06 1991 df2',
#  '06 1991 joe',
#  '06 2015',
#  '06 2015 author',
#  '06 2016',
#  '06 2016 idea',
#  '06 2016 sorted',
#  '06 21',
#  '06 21 culebra',
#  '06 california',
#  '06 california drought',
#  '06 firebird',
#  '06 firebird database',
#  '06 introducing',
#  '06 introducing android',
#  '0627',
#  '0627 0628',
#  '0627 0628 0633',
#  '0627 0628 0645',
#  '0627 0631',
#  '0627 0631 06a9',
#  '0627 0645',
#  '0627 0645 062f',
#  '0627 0646',
#  '0627 0646 06cc',
#  '0627 self',
#  '0627 self adapter',
#  '0628',
#  '0628 0633',
#  '0628 0633 06cc',
#  '0628 0645',
#  '0628 0645 06cc',
#  '062a',
#  '062a 0627',
#  '062a 0627 0628',
#  '062e',
#  '062e 0648',
#  '062e 0648 0627',
#  '062f',
#  '062f 0646',
#  '062f 0646 06cc',
#  '0631',
#  '0631 06a9',
#  '0631 06a9 062a',
#  '0633',
#  '0633 0644',
#  '0633 0644 0627',
#  '0633 06cc',
#  '0633 06cc 0627',
#  '0636920022596',
#  '0636920022596 application',
#  '0636920022596 application security',
#  '0644',
#  '0644 0627',
#  '0644 0627 0645',
#  '0645',
#  '0645 0627',
#  '0645 0627 0628',
#  '0645 062f',
#  '0645 062f 0646',
#  '0645 06cc',
#  '0645 06cc 200c',
#  '0645 u0645',
#  '0645 u0645 u0627',
#  '0646',
#  '0646 06cc',
#  '0646 06cc 0627',
#  '0646 06cc 0645',
#  '0648',
#  '0648 0627',
#  '0648 0627 0646',
#  '06a9',
#  '06a9 062a',
#  '06a9 062a 0627',
#  '06cc',
#  '06cc 0627',
#  '06cc 0627 0631',
#  '06cc 0627 self',
#  '06cc 0645',
#  '06cc 0645 u0645',
#  '06cc 200c',
#  '06cc 200c 062e',
#  '07',
#  '07 09',
#  '07 09 12',
#  '07 09 13',
#  '07 09 14',
#  '07 09 15',
#  '07 09 16',
#  '07 09 17',
#  '07 2015',
#  '07 2015 eintragstyp',
#  '07 31',
#  '07 31 2014sep19_at_182325',
#  '07 improved_regex_for_matching_urls',
#  '07 improved_regex_for_matching_urls rel',
#  '0715086071862673e301',
#  '0715086071862673e301 code',
#  '0715086071862673e301 code result',
#  '08',
#  '08 01',
#  '08 01 html',
#  '08 1993',
#  '08 1993 06',
#  '08 1993 lisa',
#  '08 jython',
#  '08 jython 27',
#  '08 msc',
#  '08 msc 32',
#  '08 run',
#  '08 run cherrypy',
#  '08 ubuntu',
#  '08 ubuntu linux',
#  '084',
#  '084 prob',
#  '084 prob jb',
#  '09',
#  '09 12',
#  '09 12 00',
#  '09 12 turn',
#  '09 13',
#  '09 13 00',
#  '09 14',
#  '09 14 00',
#  '09 15',
#  '09 15 00',
#  '09 16',
#  '09 16 00',
#  '09 17',
#  '09 17 00',
#  '09 1990',
#  '09 1990 03',
#  '09 1990 debby',
#  '09 27',
#  '09 27 13',
#  '09 57',
#  '09 57 2016',
#  '09 androidviewclientculebra',
#  '09 androidviewclientculebra takesnapshot',
#  '0_29',
#  '0_29 b11',
#  '0_29 b11 402',
#  '0_29 java',
#  '0_29 java tm',
#  '0ahukewjcwcka6f3nahxnyomkhuvkansq6aeihdaa',
#  '0ahukewjcwcka6f3nahxnyomkhuvkansq6aeihdaa onepage',
#  '0ahukewjcwcka6f3nahxnyomkhuvkansq6aeihdaa onepage amp',
#  '0b1101',
#  '0b1101 reversing',
#  '0b1101 reversing just',
#  '0b1wo07',
#  '0b1wo07 ol50_btr0selrltzgweu',
#  '0b1wo07 ol50_btr0selrltzgweu rel',
#  '0bystufvtfzjmm3pyevriwmxslvu',
#  '0bystufvtfzjmm3pyevriwmxslvu view',
#  '0bystufvtfzjmm3pyevriwmxslvu view contains',
#  '0bystufvtfzjmm3pyevriwmxslvu view rel',
#  '0no',
#  '0no 2668',
#  '0no 2668 ed',
#  '0o10',
#  '0o10 py3',
#  '0o10 py3 0b1101',
#  '0x',
#  '0x code',
#  '0x code don',
#  '0x code java',
#  '0x00008000',
#  '0x00008000 global',
#  '0x00008000 global wm_devicechange',
#  '0x0219',
#  '0x0219 global',
#  '0x0219 global drives',
#  '0x10',
#  '0x10 010',
#  '0x10 010 0o10',
#  '0x10da6d878',
#  '0x10da6d878 gt',
#  '0x10da6d878 gt code',
#  '0x11ef11c41cf98b00l',
#  '0x11ef11c41cf98b00l gt',
#  '0x11ef11c41cf98b00l gt gt',
#  '0x1d50059a',
#  '0x1d50059a 0x4f75fb90',
#  '0x1d50059a 0x4f75fb90 gt',
#  '0x1d50059e',
#  '0x1d50059e 0x4f75fb80',
#  '0x1d50059e 0x4f75fb80 gt',
#  '0x1d5005a2',
#  '0x1d5005a2 0x4f75fb70',
#  '0x1d5005a2 0x4f75fb70 gt',
#  '0x1d5005a6',
#  '0x1d5005a6 0x4f75fb60',
#  '0x1d5005a6 0x4f75fb60 gt',
#  '0x1d5005aa',
#  '0x1d5005aa 0x4f75fb50',
#  '0x1d5005aa 0x4f75fb50 gt',
#  '0x1d5005ae',
#  '0x1d5005ae 0x4f75fb40',
#  '0x1d5005ae 0x4f75fb40 gt',
#  '0x1d6005b2',
#  '0x1d6005b2 0x4f75fb30',
#  '0x1d6005b2 0x4f75fb30 gt',
#  '0x1d6005b6',
#  '0x1d6005b6 0x4f75fb20',
#  '0x1d6005b6 0x4f75fb20 gt',
#  '0x1d6005ba',
#  '0x1d6005ba 0x4f75fb10',
#  '0x1d6005ba 0x4f75fb10 gt',
#  '0x1d6005be',
#  '0x1d6005be 0x4f75fb00',
#  '0x1d6005be 0x4f75fb00 gt',
#  '0x1d6005c2',
#  '0x1d6005c2 0x4f75faf0',
#  '0x1d6005c2 0x4f75faf0 gt',
#  '0x1d6005c6',
#  '0x1d6005c6 0x4f75fae0',
#  '0x1d6005c6 0x4f75fae0 gt',
#  '0x1d6005ca',
#  '0x1d6005ca 0x4f75fad0',
#  '0x1d6005ca 0x4f75fad0 gt',
#  '0x1d6005ce',
#  '0x1d6005ce 0x4f75fac0',
#  '0x1d6005ce 0x4f75fac0 gt',
#  '0x1d6005d2',
#  '0x1d6005d2 0x4f75fab0',
#  '0x1d6005d2 0x4f75fab0 gt',
#  '0x1d6005d6',
#  '0x1d6005d6 0x4f75faa0',
#  '0x1d6005d6 0x4f75faa0 gt',
#  '0x1d6005da',
#  '0x1d6005da 0x4f75fa90',
#  '0x1d6005da 0x4f75fa90 gt',
#  '0x1d7005e2',
#  '0x1d7005e2 0x4f75fa70',
#  '0x1d7005e2 0x4f75fa70 gt',
#  '0x1d7005e6',
#  '0x1d7005e6 0x4f75fa60',
#  '0x1d7005e6 0x4f75fa60 gt',
#  '0x1d7005ea',
#  '0x1d7005ea 0x4f75fa50',
#  '0x1d7005ea 0x4f75fa50 gt',
#  '0x1d7005ee',
#  '0x1d7005ee 0x4f75fa40',
#  '0x1d7005ee 0x4f75fa40 gt',
#  '0x1d7005f2',
#  '0x1d7005f2 0x4f75f5d0',
#  '0x1d7005f2 0x4f75f5d0 gt',
#  '0x1d7005f6',
#  '0x1d7005f6 0x4f75fa10',
#  '0x1d7005f6 0x4f75fa10 gt',
#  '0x1d70060e',
#  '0x1d70060e 0x4f75f9b0',
#  '0x1d70060e 0x4f75f9b0 gt',
#  '0x1d700612',
#  '0x1d700612 0x4f75f9a0',
#  '0x1d700612 0x4f75f9a0 gt',
#  '0x1d700616',
#  '0x1d700616 0x4f75f990',
#  '0x1d700616 0x4f75f990 gt',
#  '0x1d70061a',
#  '0x1d70061a 0x4f75f980',
#  '0x1d70061a 0x4f75f980 gt',
#  '0x1d70061e',
#  '0x1d70061e 0x4f75f970',
#  '0x1d70061e 0x4f75f970 gt',
#  '0x1d700622',
#  '0x1d700622 0x4f75f960',
#  '0x1d700622 0x4f75f960 gt',
#  '0x1d700626',
#  '0x1d700626 0x4f75f950',
#  '0x1d700626 0x4f75f950 gt',
#  '0x1d70062a',
#  '0x1d70062a 0x4f75f940',
#  '0x1d70062a 0x4f75f940 gt',
#  '0x1d70062e',
#  '0x1d70062e 0x4f75f930',
#  '0x1d70062e 0x4f75f930 gt',
#  '0x1d700632',
#  '0x1d700632 0x4f75f920',
#  '0x1d700632 0x4f75f920 gt',
#  '0x1d700636',
#  '0x1d700636 0x4f75f910',
#  '0x1d700636 0x4f75f910 gt',
#  '0x1d70063a',
#  '0x1d70063a 0x4f75f900',
#  '0x1d70063a 0x4f75f900 gt',
#  '0x1d70063e',
#  '0x1d70063e 0x4f75f8f0',
#  '0x1d70063e 0x4f75f8f0 gt',
#  '0x1d700642',
#  '0x1d700642 0x4f75f8e0',
#  '0x1d700642 0x4f75f8e0 gt',
#  '0x1d700646',
#  '0x1d700646 0x4f75f8d0',
#  '0x1d700646 0x4f75f8d0 gt',
#  '0x1d70064a',
#  '0x1d70064a 0x4f75f8c0',
#  '0x1d70064a 0x4f75f8c0 gt',
#  '0x1d70064e',
#  '0x1d70064e 0x4f75f8b0',
#  '0x1d70064e 0x4f75f8b0 gt',
#  '0x1d700652',
#  '0x1d700652 0x4f75f8a0',
#  '0x1d700652 0x4f75f8a0 gt',
#  '0x1d700656',
#  '0x1d700656 0x4f75f890',
#  '0x1d700656 0x4f75f890 gt',
#  '0x1d70065a',
#  '0x1d70065a 0x4f75f870',
#  '0x1d70065a 0x4f75f870 gt',
#  '0x1d70065e',
#  '0x1d70065e 0x4f75f880',
#  '0x1d70065e 0x4f75f880 gt',
#  '0x1d700662',
#  '0x1d700662 0x4f75f340',
#  '0x1d700662 0x4f75f340 gt',
#  '0x1d700666',
#  '0x1d700666 0x4f75f7a0',
#  '0x1d700666 0x4f75f7a0 gt',
#  '0x1d70066a',
#  '0x1d70066a 0x4f75f780',
#  '0x1d70066a 0x4f75f780 gt',
#  '0x1d70066e',
#  '0x1d70066e 0x4f75f3f0',
#  '0x1d70066e 0x4f75f3f0 gt',
#  '0x1d8005fa',
#  '0x1d8005fa 0x4f75fa00',
#  '0x1d8005fa 0x4f75fa00 gt',
#  '0x1d8005fe',
#  '0x1d8005fe 0x4f75f9f0',
#  '0x1d8005fe 0x4f75f9f0 gt',
#  '0x1d800676',
#  '0x1d800676 0x4f75f750',
#  '0x1d800676 0x4f75f750 gt',
#  '0x1d80067a',
#  '0x1d80067a 0x4f75f740',
#  '0x1d80067a 0x4f75f740 gt',
#  '0x1d80067e',
#  '0x1d80067e 0x4f75f730',
#  '0x1d80067e 0x4f75f730 gt',
#  '0x1d800682',
#  '0x1d800682 0x4f75f720',
#  '0x1d800682 0x4f75f720 gt',
#  '0x1d800686',
#  '0x1d800686 0x4f75f700',
#  '0x1d800686 0x4f75f700 gt',
#  '0x1da00602',
#  '0x1da00602 0x4f75f9e0',
#  '0x1da00602 0x4f75f9e0 gt',
#  '0x1da00696',
#  '0x1da00696 0x4f75f7b0',
#  '0x1da00696 0x4f75f7b0 gt',
#  '0x1f36f50',
#  '0x1f36f50 gt',
#  '0x1f36f50 gt code',
#  '0x1f8005de',
#  '0x1f8005de 0x4f75fa80',
#  '0x1f8005de 0x4f75fa80 gt',
#  '0x20400672',
#  '0x20400672 0x4f75f760',
#  '0x20400672 0x4f75f760 gt',
#  '0x22b00606',
#  '0x22b00606 0x4f75f9d0',
#  '0x22b00606 0x4f75f9d0 gt',
#  '0x2be0060a',
#  '0x2be0060a 0x4f75f9c0',
#  '0x2be0060a 0x4f75f9c0 gt',
#  '0x43',
#  '0x43 0xd2',
#  '0x43 0xd2 0xce',
#  '0x4f75f340',
#  '0x4f75f340 gt',
#  '0x4f75f340 gt gt',
#  '0x4f75f3f0',
#  '0x4f75f3f0 gt',
#  '0x4f75f3f0 gt gt',
#  '0x4f75f5d0',
#  '0x4f75f5d0 gt',
#  '0x4f75f5d0 gt gt',
#  '0x4f75f700',
#  '0x4f75f700 gt',
#  '0x4f75f700 gt gt',
#  '0x4f75f720',
#  '0x4f75f720 gt',
#  '0x4f75f720 gt gt',
#  '0x4f75f730',
#  '0x4f75f730 gt',
#  '0x4f75f730 gt gt',
#  '0x4f75f740',
#  '0x4f75f740 gt',
#  '0x4f75f740 gt gt',
#  '0x4f75f750',
#  '0x4f75f750 gt',
#  '0x4f75f750 gt gt',
#  '0x4f75f760',
#  '0x4f75f760 gt',
#  '0x4f75f760 gt gt',
#  '0x4f75f780',
#  '0x4f75f780 gt',
#  '0x4f75f780 gt gt',
#  '0x4f75f7a0',
#  '0x4f75f7a0 gt',
#  '0x4f75f7a0 gt gt',
#  '0x4f75f7b0',
#  '0x4f75f7b0 gt',
#  '0x4f75f7b0 gt gt',
#  '0x4f75f870',
#  '0x4f75f870 gt',
#  '0x4f75f870 gt gt',
#  '0x4f75f880',
#  '0x4f75f880 gt',
#  '0x4f75f880 gt gt',
#  '0x4f75f890',
#  '0x4f75f890 gt',
#  '0x4f75f890 gt gt',
#  '0x4f75f8a0',
#  '0x4f75f8a0 gt',
#  '0x4f75f8a0 gt gt',
#  '0x4f75f8b0',
#  '0x4f75f8b0 gt',
#  '0x4f75f8b0 gt gt',
#  '0x4f75f8c0',
#  '0x4f75f8c0 gt',
#  '0x4f75f8c0 gt gt',
#  '0x4f75f8d0',
#  '0x4f75f8d0 gt',
#  '0x4f75f8d0 gt gt',
#  '0x4f75f8e0',
#  '0x4f75f8e0 gt',
#  '0x4f75f8e0 gt gt',
#  '0x4f75f8f0',
#  '0x4f75f8f0 gt',
#  '0x4f75f8f0 gt gt',
#  '0x4f75f900',
#  '0x4f75f900 gt',
#  '0x4f75f900 gt gt',
#  '0x4f75f910',
#  '0x4f75f910 gt',
#  '0x4f75f910 gt gt',
#  '0x4f75f920',
#  '0x4f75f920 gt',
#  '0x4f75f920 gt gt',
#  '0x4f75f930',
#  ...]

# %% [markdown]
# #### Question 2: The dimensionality explodes quickly. Why might this be a problem as you use more data?

# %% [markdown]
# <b>As you get more data the increase in number of features outpaces the increase in the number of cases, which would make it difficult to do any statistical analysis.</b> Also, you wind up using a lot of memory with a sparsly populated matrix.

# %% [markdown]
# Calculate the tf-idf scores for the first document in the corpus. Do the following:
#
# 1. Use ".todense()" to turn the tfidf matrix into a dense matrix (get rid of the sparsity)
# 2. Create an object for th document by calling the 0th index of the dense matrix, converting it to a list. Try something like: document = dense[0].tolist()[0]
# 3. Calculate the phrase scores by using the "zip" command to iterate from 0 to the length of the document, retaining scores greater than 0.
# 4. Sort the scores using the "sorted" command
# 5. Print the top 20 scores with their feature names

# %%
dense = tfidf_matrix.todense()
document = dense[0].tolist()[0]
print(type(document))
print('length of list', len(document))
#document
# Out:
# <class 'list'>
# length of list 154834

# %%
# my attempt to make a list of nonzero scores
#score_list = []
#for scores in document:
#    if scores > 0: 
#        score_list.append(scores)
#score_list[:5]

# %%
document = dense[0].tolist()[0]
phrase_scores = [pair for pair in zip(range(0, len(document)), document) if pair[1] > 0]

# %%
sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1] * -1)
for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
   print('{0: <20} {1}'.format(phrase, score))
# Out:
# client id            0.32019367562186724
# apps googleusercontent 0.21346245041457818
# apps googleusercontent com 0.21346245041457818
# client id apps       0.21346245041457818
# googleusercontent    0.21346245041457818
# googleusercontent com 0.21346245041457818
# id apps              0.21346245041457818
# id apps googleusercontent 0.21346245041457818
# id                   0.18191630128131922
# client               0.18075804350384492
# android client id    0.16009683781093362
# web client           0.16009683781093362
# web client id        0.16009683781093362
# android client       0.14644948882613879
# apps                 0.1432608330582954
# android_client_id    0.10673122520728909
# android_client_id android 0.10673122520728909
# android_client_id android client 0.10673122520728909
# code web_client_id   0.10673122520728909
# code web_client_id web 0.10673122520728909

# %% [markdown]
# # Section 2: Classification Algorithms

# %% [markdown]
# One of the main tasks in supervised machine learning is classification. In this case, we will develop algorithms that will predict a question's tag based on the text of its answer.
#
# The first step is to split our data into training, validation, and test sets.

# %%
# Training, Validation, Test Sets

# X
X = stack_data['Body']
tf = TfidfVectorizer(analyzer='word', 
                     ngram_range=(1,3), 
                     min_df = 0, 
                     stop_words = 'english')

tfidf_matrix =  tf.fit_transform(X)

#y

y = stack_data['Tag']

# Train/Test Split
X_train, X_test, y_train, y_test = train_test_split(tfidf_matrix, y,
                                                   train_size = .80,
                                                   test_size = .20)

# Train/Validation Split
X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train,
                                                           train_size = .75,
                                                           test_size = .25)

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# [Naive Bayes classifers](http://scikit-learn.org/stable/modules/naive_bayes.html) classify observations by making the assumption that features are all independent of one another. Do the following:
#
# 1. Initialize a Naive Bayes classifier method with "MultinomialNB()"
# 2. Fit the model on your training data
# 3. Predict on the validation data and store the predictions
# 4. Use "np.mean" to calculate how correct the classier was on average
# 5. Calcualte the confusion matrix using "confusion_matrix," providing the true values first and the predicted values second.

# %%
nb = MultinomialNB()

# %%
nb_model = nb.fit(X_train, y_train)

# %%
nb_preds = nb_model.predict(X_validate)

# %%
np.mean(nb_preds == y_validate)
# Out:
# 0.71599999999999997

# %%
nb_cf_matrix = confusion_matrix(y_validate, nb_preds)

# %% [markdown]
# Let's plot the confusion matrix! Use the following code from the ["seaborn"](https://seaborn.pydata.org/generated/seaborn.heatmap.html) package to make a heatmap out of the matrix.

# %%
# Transform confusion matrix into a dataframe
nb_df_cm = pd.DataFrame(nb_cf_matrix, range(5),
                  range(5))

# Rename the column and row indices
nb_df_cm = nb_df_cm.rename(index=str, columns={0: "python", 1: "xml", 2: "java", 3: "json", 4: "android"})
nb_df_cm.index = ['python', 'xml', 'java', 'json', 'android']

# Plot the confusion matrix
plt.figure(figsize = (10,7))
sn.set(font_scale=1.4)#for label size
sn.heatmap(nb_df_cm, 
           annot=True,
           annot_kws={"size": 16})

plt.title("Naive Bayes Confusion Matrix")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# #### Question 3: Do you notice any patterns? Are there any patterns in misclassification that are worrisome?

# %% [markdown]
# ### the naive Bayes predictor does not seem great at classifying xml or json, especially the latter, to the extent that you probably would not want to trust the classifier for those. It does pretty good for python and java and great for android documents.

# %% [markdown]
# ## Multinomial Logistic Regression

# %% [markdown]
# Next, let's try [multinomial logistic regression](http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html)! Follow the same steps as with Naive Bayes, and plot the confusion matrix.

# %% [markdown]
# ## SVM

# %% [markdown]
# Now do the same for a [Support Vector Machine](http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html).

# %% [markdown]
# #### Question 4: How did each of the classifiers do? Which one would you prefer the most?

# %% [markdown]
# ## Test Final Classifier

# %% [markdown]
# Choose your best classifier and use it to predict on the test set. Report the mean accuracy and confusion matrix.
